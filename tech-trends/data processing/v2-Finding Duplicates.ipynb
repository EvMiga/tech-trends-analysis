# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
df.duplicated().sum()
# Out:
# np.int64(20)

# %%
df[df.duplicated(keep=False)].head(2)
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
#
#                                         EdLevel  \
# 0                     Primary/elementary school
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# ...

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
## Write your code here
dup_rows=df[df.duplicated(subset=['MainBranch', 'Employment', 'RemoteWork'])]
print(dup_rows.head())
# Считаем количество уникальных значений в дублирующихся строках
unique_counts = dup_rows.nunique().sort_values()

unique_counts
# Out:
#     ResponseId                      MainBranch                 Age  \
# 1            2  I am a developer by profession     35-44 years old
# 2            3  I am a developer by profession     45-54 years old
# 14          15  I am a developer by profession     25-34 years old
# 15          16  I am a developer by profession     45-54 years old
# 16          17     I code primarily as a hobby  Under 18 years old
#
#              Employment                            RemoteWork   Check  \
# 1   Employed, full-time                                Remote  Apples
# 2   Employed, full-time                                Remote  Apples
# 14  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 15  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 16   Student, full-time                                   NaN  Apples
#
#                                      CodingActivities  \
# 1   Hobby;Contribute to open-source projects;Other...
# ...

# %%
dup_rows[['MainBranch', 'Employment', 'RemoteWork']]
# Out:
#                                               MainBranch  \
# 1                         I am a developer by profession
# 2                         I am a developer by profession
# 14                        I am a developer by profession
# 15                        I am a developer by profession
# 16                           I code primarily as a hobby
# ...                                                  ...
# 65452  I am not primarily a developer, but I write co...
# 65453                     I am a developer by profession
# 65454                     I am a developer by profession
# 65455                     I am a developer by profession
# 65456                     I am a developer by profession
#
#                                               Employment  \
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 14                                   Employed, full-time
# ...

# %%
country_counts = dup_rows['Country'].value_counts()
country_counts
# Out:
# Country
# United States of America                                10999
# Germany                                                  4921
# India                                                    4198
# United Kingdom of Great Britain and Northern Ireland     3210
# Ukraine                                                  2641
#                                                         ...
# Micronesia, Federated States of...                          1
# Nauru                                                       1
# Chad                                                        1
# Djibouti                                                    1
# Solomon Islands                                             1
# Name: count, Length: 185, dtype: int64

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
## Write your code here
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
country_counts.head(30).plot(kind='bar')
plt.title("Распределение уникальных значений по столбцам\n(дублирующиеся строки)")
plt.xlabel("columns")
plt.ylabel("number of unique")
plt.xticks(rotation=100)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
country_counts.plot(kind='pie',
                 autopct='%1.1f%%',
                 startangle=90,
                 shadow=True)
plt.ylabel('')
plt.title('Распределение уникальных значений по столбцам')
plt.tight_layout()
plt.show()

# %%
employment_counts = dup_rows['Employment'].value_counts()

# %%
plt.figure(figsize=(15,9))
employment_counts.plot(kind='bar', color='lightgreen')
plt.title('Распределение дубликатов по типу занятости')
plt.xlabel('Тип занятости')
plt.ylabel('Количество дубликатов')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\chebo\AppData\Local\Temp\ipykernel_15856\451122002.py:7: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
## Write your code here
uniq_ratio = df.nunique()/len(df)
uniq_rat = uniq_ratio.sort_values(ascending=False)
uniq_rat.head(20)
# Out:
# ResponseId                        0.999694
# LanguageHaveWorkedWith            0.364575
# LanguageWantToWorkWith            0.347847
# ToolsTechHaveWorkedWith           0.303757
# ToolsTechWantToWorkWith           0.252822
# NEWCollabToolsHaveWorkedWith      0.216447
# LanguageAdmired                   0.188444
# WebframeHaveWorkedWith            0.186917
# ToolsTechAdmired                  0.180332
# WebframeWantToWorkWith            0.178041
# LearnCodeOnline                   0.165804
# MiscTechWantToWorkWith            0.156790
# NEWCollabToolsWantToWorkWith      0.148968
# MiscTechHaveWorkedWith            0.141895
# DatabaseHaveWorkedWith            0.138259
# DatabaseWantToWorkWith            0.129520
# NEWCollabToolsAdmired             0.115267
# ConvertedCompYearly               0.093390
# OfficeStackAsyncHaveWorkedWith    0.091877
# PlatformHaveWorkedWith            0.083520
# dtype: float64

# %%
subset_cols = ['MainBranch', 'Employment', 'RemoteWork']
dublicated_clean = df.drop_duplicates(subset_cols, keep="first")

# %%
dublicated_clean.head()
# Out:
#       ResponseId                                         MainBranch  \
# 1078        1079  I am not primarily a developer, but I write co...
# 1086        1087                     I am a developer by profession
# 1104        1105                     I am a developer by profession
# 1483        1484                     I am a developer by profession
# 1918        1919                        I code primarily as a hobby
#
#                     Age                                         Employment  \
# 1078    18-24 years old  Independent contractor, freelancer, or self-em...
# 1086  Prefer not to say  Independent contractor, freelancer, or self-em...
# 1104    25-34 years old  Student, full-time;Not employed, but looking f...
# 1483    35-44 years old                        Employed, full-time;Retired
# 1918    35-44 years old  Not employed, but looking for work;Independent...
#
#      RemoteWork   Check                                   CodingActivities  \
# ...

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# Процесс выявления и удаления дубликатов
#
# Процесс удаления дубликатов включал несколько последовательных этапов.
#
# На первом этапе данные были загружены и проведён первичный анализ их объёма. Это позволило определить общее количество строк и выявить наличие дублирующихся записей. Далее был выполнен анализ дубликатов с целью понять их структуру и характер — являются ли они полными дубликатами строк или логическими повторениями.
#
# На втором этапе были проанализированы характеристики дублирующихся строк на основе подмножеств столбцов.
#
# На третьем этапе было выполнено визуальное исследование распределения дубликатов по ключевым категориям, таким как страна и тип занятости. Для этого использовались графики, которые наглядно показали, в каких категориях дубликаты встречаются наиболее часто и какие из них являются наиболее значимыми с точки зрения дальнейшего анализа.
#
# На основе полученных визуализаций и анализа структуры дубликатов была выбрана стратегия удаления дубликатов. Было принято решение не удалять все дублирующиеся записи полностью, поскольку полное совпадение строк не является корректным критерием для данного набора данных. Вместо этого дубликаты удалялись на основе выбранного подмножества ключевых столбцов, при этом для каждой уникальной комбинации сохранялась первая запись (keep='first').
#
# Целью данного подхода было упрощение структуры данных и устранение избыточных записей без потери значимой информации. Это позволило облегчить построение аналитических метрик, повысить интерпретируемость данных и обеспечить более корректный последующий анализ.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# Для этого были выбраны наиболее значимые столбцы, которые используются для определения уникальности записей. Анализ позволил определить, какие столбцы чаще всего содержат одинаковые значения в дублирующихся строках и, следовательно, оказывают наибольшее влияние на формирование дубликатов

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
