# %%
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# ...

# %%
la = df[['LanguageWantToWorkWith',
            'DatabaseWantToWorkWith',
            'PlatformWantToWorkWith',
            'WebframeWantToWorkWith',
            'LearnCode',
            'EdLevel'
]].dropna()
new_df
# Out:
#                                   LanguageWantToWorkWith  \
# 1      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                     C#
# 3      HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 7                         HTML/CSS;JavaScript;TypeScript
# ...                                                  ...
# 65351  Bash/Shell (all shells);C;C++;HTML/CSS;Java;Ja...
# 65367                      Go;JavaScript;Rust;TypeScript
# 65401       C#;HTML/CSS;JavaScript;Python;SQL;TypeScript
# 65409                     HTML/CSS;JavaScript;PowerShell
# 65431  Bash/Shell (all shells);C#;Go;HTML/CSS;Java;Ja...
#
#                                   DatabaseWantToWorkWith  \
# 1                                             PostgreSQL
# 2                             Firebase Realtime Database
# 3                               MongoDB;MySQL;PostgreSQL
# ...

# %%
pl=df[['PlatformWantToWorkWith','PlatformHaveWorkedWith']].dropna()
pl.loc[:,'PlatformWantToWorkWith'] = pl['PlatformWantToWorkWith'].str.split(';')
pl = pl.explode('PlatformWantToWorkWith')
pl.loc[:,'PlatformHaveWorkedWith'] = pl['PlatformHaveWorkedWith'].str.split(';')
pl = pl.explode('PlatformHaveWorkedWith')
pl
# Out:
#           PlatformWantToWorkWith     PlatformHaveWorkedWith
# 1      Amazon Web Services (AWS)  Amazon Web Services (AWS)
# 1      Amazon Web Services (AWS)                     Heroku
# 1      Amazon Web Services (AWS)                    Netlify
# 1                         Heroku  Amazon Web Services (AWS)
# 1                         Heroku                     Heroku
# ...                          ...                        ...
# 65436                     Vercel  Amazon Web Services (AWS)
# 65436                     Vercel                 Cloudflare
# 65436                     Vercel               Google Cloud
# 65436                     Vercel                    Netlify
# 65436                     Vercel                     Vercel
#
# [276696 rows x 2 columns]

# %%
wb=df[['WebframeWantToWorkWith','WebframeHaveWorkedWith']].dropna()
wb.loc[:,'WebframeWantToWorkWith'] = wb['WebframeWantToWorkWith'].str.split(';')
wb = wb.explode('WebframeWantToWorkWith')
wb.loc[:,'WebframeHaveWorkedWith'] = wb['WebframeHaveWorkedWith'].str.split(';')
wb = wb.explode('WebframeHaveWorkedWith')
wb
# Out:
#       WebframeWantToWorkWith WebframeHaveWorkedWith
# 1                    Express                Express
# 1                    Express                Next.js
# 1                    Express                Node.js
# 1                    Express                  React
# 1                       Htmx                Express
# ...                      ...                    ...
# 65436                  React                Express
# 65436                  React                 jQuery
# 65436                  React                Next.js
# 65436                  React                Node.js
# 65436                  React                  React
#
# [641547 rows x 2 columns]

# %%
db=df[['DatabaseWantToWorkWith','DatabaseHaveWorkedWith']].dropna()
db.loc[:,'DatabaseWantToWorkWith'] = db['DatabaseWantToWorkWith'].str.split(';')
db = db.explode('DatabaseWantToWorkWith')
db.loc[:,'DatabaseHaveWorkedWith'] = db['DatabaseHaveWorkedWith'].str.split(';')
db = db.explode('DatabaseHaveWorkedWith')
db
# Out:
#            DatabaseWantToWorkWith      DatabaseHaveWorkedWith
# 1                      PostgreSQL                    Dynamodb
# 1                      PostgreSQL                     MongoDB
# 1                      PostgreSQL                  PostgreSQL
# 2      Firebase Realtime Database  Firebase Realtime Database
# 3                         MongoDB                     MongoDB
# ...                           ...                         ...
# 65436                       MySQL                  PostgreSQL
# 65436                  PostgreSQL                     MongoDB
# 65436                  PostgreSQL                       MySQL
# 65436                  PostgreSQL                      Oracle
# 65436                  PostgreSQL                  PostgreSQL
#
# [536018 rows x 2 columns]

# %%
new_df = new_df.reset_index(drop=True)

# %%
la=df[['LanguageWantToWorkWith', 'LanguageHaveWorkedWith']].dropna()
la.loc[:,'LanguageWantToWorkWith'] = la['LanguageWantToWorkWith'].str.split(';')
la = la.explode('LanguageWantToWorkWith')
la.loc[:,'LanguageHaveWorkedWith'] = la['LanguageHaveWorkedWith'].str.split(';')
la= la.explode('LanguageHaveWorkedWith')
la
# Out:
#         LanguageWantToWorkWith   LanguageHaveWorkedWith
# 1      Bash/Shell (all shells)  Bash/Shell (all shells)
# 1      Bash/Shell (all shells)                       Go
# 1      Bash/Shell (all shells)                 HTML/CSS
# 1      Bash/Shell (all shells)                     Java
# 1      Bash/Shell (all shells)               JavaScript
# ...                        ...                      ...
# 65436               TypeScript                     Java
# 65436               TypeScript               JavaScript
# 65436               TypeScript                      PHP
# 65436               TypeScript                   Python
# 65436               TypeScript               TypeScript
#
# [1798291 rows x 2 columns]

# %%
new_df = new_df.reset_index(drop=True)

# %%
# --- 4. сохранить CSV ---
pl.to_csv('platform_survey-data.csv', index=False, encoding='utf-8-sig')
wb.to_csv('web_survey-data.csv', index=False, encoding='utf-8-sig')
db.to_csv('DataBase_survey-data.csv', index=False, encoding='utf-8-sig')
la.to_csv('language_survey-data.csv', index=False, encoding='utf-8-sig')
print("Готово. Файлы сохранёны")
# Out:
# Готово. Файлы сохранёны

# %%
df_2=df[['LanguageHaveWorkedWith',
    'DatabaseHaveWorkedWith',
    'PlatformHaveWorkedWith',
    'WebframeHaveWorkedWith']].dropna()

# %%
# --- по одному столбцу: split -> explode ---
df_2.loc[:,'LanguageHaveWorkedWith'] = new_df['LanguageHaveWorkedWith'].str.split(';')
df_2 = df_2.explode('LanguageHaveWorkedWith')

# %%
# --- 4. сохранить CSV ---
new_2.to_csv('new_survey-data.csv', index=False, encoding='utf-8-sig')

print("Готово. Файл сохранён как new_survey-data.csv")

# %%
new_df['LanguageHaveWorkedWith']
